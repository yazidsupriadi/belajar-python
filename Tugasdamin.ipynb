# %% [markdown]
# <a href="https://colab.research.google.com/github/yazidsupriadi/belajar-python/blob/master/Tugasdamin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_excel('dataset.xlsx')
dataset.head()
# Out:
#    Row ID Order Priority  Discount  ...  Quantity ordered new    Sales  Order ID
# 0   20847           High      0.01  ...                     4    13.01     88522
# 1   20228  Not Specified      0.02  ...                    12  6362.85     90193
# 2   21776       Critical      0.06  ...                    22   211.15     90192
# 3   24844         Medium      0.09  ...                    16  1164.45     86838
# 4   24846         Medium      0.08  ...                     7    22.23     86838
#
# [5 rows x 25 columns]

# %% [markdown]
# cari missing value

# %%
dataset.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   1
# State or Province        0
# City                     0
# Postal Code              1
# Order Date               0
# Ship Date                0
# Profit                   1
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
df = pd.DataFrame(dataset)
df
# Out:
#       Row ID Order Priority  Discount  ...  Quantity ordered new    Sales  Order ID
# 0      20847           High      0.01  ...                     4    13.01     88522
# 1      20228  Not Specified      0.02  ...                    12  6362.85     90193
# 2      21776       Critical      0.06  ...                    22   211.15     90192
# 3      24844         Medium      0.09  ...                    16  1164.45     86838
# 4      24846         Medium      0.08  ...                     7    22.23     86838
# ...      ...            ...       ...  ...                   ...      ...       ...
# 1947   19842           High      0.01  ...                    18   207.31     87536
# 1948   19843           High      0.10  ...                    22   143.12     87536
# 1949   26208  Not Specified      0.08  ...                     5    59.98     87534
# 1950   24911         Medium      0.10  ...                    15   135.78     87537
# 1951   25914           High      0.10  ...                     5   506.50     87530
#
# [1952 rows x 25 columns]

# %%
dataset['Profit'].fillna(dataset['Profit'].mean(),inplace=True)
dataset['Product Base Margin'].fillna(dataset['Product Base Margin'].mean(),inplace=True)

# %%
df
# Out:
#       Row ID Order Priority  Discount  ...  Quantity ordered new    Sales  Order ID
# 0      20847           High      0.01  ...                     4    13.01     88522
# 1      20228  Not Specified      0.02  ...                    12  6362.85     90193
# 2      21776       Critical      0.06  ...                    22   211.15     90192
# 3      24844         Medium      0.09  ...                    16  1164.45     86838
# 4      24846         Medium      0.08  ...                     7    22.23     86838
# ...      ...            ...       ...  ...                   ...      ...       ...
# 1947   19842           High      0.01  ...                    18   207.31     87536
# 1948   19843           High      0.10  ...                    22   143.12     87536
# 1949   26208  Not Specified      0.08  ...                     5    59.98     87534
# 1950   24911         Medium      0.10  ...                    15   135.78     87537
# 1951   25914           High      0.10  ...                     5   506.50     87530
#
# [1952 rows x 25 columns]
